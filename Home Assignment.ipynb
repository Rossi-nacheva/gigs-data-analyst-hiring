# %%
pip install uv
# Out:
# Collecting uv
#   Downloading uv-0.9.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 116.6 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.9.3
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.10/site-packages (23.0.1)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 110.1 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# Successfully installed pip-25.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create virtual environment using the correct syntax
# !uv venv
n
# Out:
# Using CPython 3.10.15 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# ? A virtual environment already exists at `.venv`. Do you want to replace it? [y/n] › yes
#
# hint: Use the `--clear` flag or set `UV_VENV_CLEAR=1` to skip this prompt

# %%
# Activate virtual environment
# !source .venv/bin/activate  
# On Windows: .venv\Scripts\activate

# %%
# Install dependencies (includes Jupyter, DuckDB, JupySQL, etc.)
# !uv pip install -r /work/requirements.txt
# Out:
# Using Python 3.10.15 environment at: /root/venv
# Resolved 123 packages in 296ms
# Prepared 83 packages in 790ms
# Installed 83 packages in 140ms
#  + anyio==4.11.0
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==25.1.0
#  + arrow==1.3.0
#  + async-lru==2.0.5
#  + backoff==2.2.1
#  + beautifulsoup4==4.14.2
#  + black==25.9.0
#  + bleach==6.2.0
#  + comm==0.2.3
#  + debugpy==1.8.17
#  + defusedxml==0.7.1
#  + distro==1.9.0
#  + duckdb==1.4.1
#  + duckdb-engine==0.17.0
#  + fastjsonschema==2.21.2
#  + fqdn==1.5.1
#  + greenlet==3.2.4
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + ipykernel==7.0.1
#  + ipython-genutils==0.2.0
#  + ipywidgets==8.1.7
#  + isoduration==20.11.0
#  + json5==0.12.1
#  + jsonpointer==3.0.0
#  + jsonschema==4.25.1
#  + jsonschema-specifications==2025.9.1
#  + jupysql==0.11.1
#  + jupysql-plugin==0.4.5
#  + jupyter==1.1.1
#  + jupyter-client==8.6.3
#  + jupyter-console==6.6.3
#  + jupyter-core==5.8.1
#  + jupyter-events==0.12.0
#  + jupyter-lsp==2.3.0
#  + jupyter-server==2.17.0
#  + jupyter-server-terminals==0.5.3
#  + jupyterlab==4.4.9
#  + jupyterlab-pygments==0.3.0
#  + jupyterlab-server==2.27.3
#  + jupyterlab-widgets==3.0.15
#  + lark==1.3.0
#  + mistune==3.1.4
#  + mypy-extensions==1.1.0
#  + nbclient==0.10.2
#  + nbconvert==7.16.6
#  + nbformat==5.10.4
#  + nest-asyncio==1.6.0
#  + notebook==7.4.7
#  + notebook-shim==0.2.4
#  + overrides==7.7.0
#  + pandocfilters==1.5.1
#  + pathspec==0.12.1
#  + ploomber-core==0.2.27
#  + posthog==6.7.7
#  + prettytable==3.16.0
#  + prometheus-client==0.23.1
#  + psutil==7.1.0
#  + python-json-logger==4.0.0
#  + pytokens==0.2.0
#  + pyzmq==27.1.0
#  + referencing==0.37.0
#  + rfc3339-validator==0.1.4
#  + rfc3986-validator==0.1.1
#  + rfc3987-syntax==1.1.0
#  + rpds-py==0.27.1
#  + send2trash==1.8.3
#  + sniffio==1.3.1
#  + soupsieve==2.8
#  + sqlalchemy==2.0.44
#  + sqlglot==27.27.0
#  + sqlparse==0.5.3
#  + terminado==0.18.1
#  + tinycss2==1.4.0
#  + tornado==6.5.2
#  + types-python-dateutil==2.9.0.20251008
#  + uri-template==1.3.0
#  + webcolors==24.11.1
#  + webencodings==0.5.1
#  + websocket-client==1.9.0
#  + widgetsnbextension==4.0.14

# %%
# The error indicates that the command 'python setup.py' was attempted to be run as Python code within a Jupyter Notebook cell.
# This command is meant to be run in a shell, not as Python code.

# To execute shell commands in Jupyter Notebook, use the '!' prefix.
# !python /work/setup.py
# Out:
# 🔍 Gigs Data Analyst Challenge - Environment Verification
# ============================================================
# ✅ uv is installed: uv 0.9.3
# ✅ Running in virtual environment: venv
#
# 📦 Checking required packages...
# ✅ duckdb: DuckDB Python client
# ✅ sql: JupySQL magic commands
# ✅ pandas: Pandas for data manipulation
# ✅ jupyter: Jupyter notebook
# ✅ duckdb_engine: DuckDB SQLAlchemy engine
# ✅ DuckDB version: 1.4.1
# ✅ DuckDB version supports required features
# 📁 Verifying data files...
# ❌ Missing: data/usage_by_subscription_period.csv
# ❌ Missing: data/plan_change_events.csv
# ❌ Missing: data/projects.csv
#
# ❌ Missing data files: ['data/usage_by_subscription_period.csv', 'data/plan_change_events.csv', 'data/projects.csv']
# 💡 Make sure you're in the data-analyst directory
# 🧪 Testing DuckDB integration...
# ✅ DuckDB basic test: Hello from DuckDB!
# ❌ Error reading data/usage_by_subscription_period.csv: IO Error: No files found that match the pattern "data/usage_by_subscription_period.csv"
# 📓 Verifying starter notebook...
# ❌ Starter notebook not found: analysis.ipynb
# 💡 Make sure you're in the data-analyst directory
# 🔬 Checking Jupyter availability...
# ✅ Jupyter Lab: 4.4.9
#
# ============================================================
# ❌ Some validation checks failed.
#
# 💡 Common fixes:
#    - Install missing packages: uv pip install -r requirements.txt
#    - Activate virtual environment: source .venv/bin/activate
#    - Ensure you're in the data-analyst directory
# ============================================================

# %%
# Import required libraries
import duckdb
import pandas as pd
from datetime import datetime, timedelta

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %%
# Load JupySQL extension and configure
# %load_ext sql

# Configure JupySQL for better output
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

print("✅ JupySQL configured!")
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# ✅ JupySQL configured!

# %%
# Connect to DuckDB
conn = duckdb.connect('gigs-analytics.db')
# %sql conn --alias duckdb

print("✅ Connected to DuckDB database: gigs-analytics.db")
# Out:
# ✅ Connected to DuckDB database: gigs-analytics.db

# %%
# %%sql
# -- Load data into DuckDB tables
# CREATE OR REPLACE TABLE usage_data AS
# SELECT * FROM 'usage_by_subscription_period.csv';
#
# CREATE OR REPLACE TABLE plan_events AS
# SELECT * FROM 'plan_change_events.csv';
#
# CREATE OR REPLACE TABLE projects AS
# SELECT * FROM read_csv_auto('projects.csv', HEADER=TRUE);
# Out:
#    Count
# 0      3

# %%
# %%sql
# -- Verify data loading
# select
#   'usage_data' as table_name,
#   count(*) as row_count,
#   count(distinct subscription_id) as unique_subscriptions
# from usage_data
# union all
# select
#   'plan_events' as table_name,
#   count(*) as row_count,
#   count(distinct plan_id) as unique_plans
# from plan_events
# union all
# select
#   'projects' as table_name,
#   count(*) as row_count,
#   count(distinct project_id__hashed) as unique_projects
# from projects;
# Out:
#     table_name  row_count  unique_subscriptions
# 0   usage_data      53565                  8457
# 1     projects          3                     3
# 2  plan_events        209                    36

# %%
# %%sql
# select *
# from projectss;
# Out:
#                                              column0       column1  \
# 0                                 project_id__hashed  project_type
# 1  dace2786aee7632e61757b320a6fe5bff37a2e742fe558...           API
# 2  82728d5d3cf7f35b58bc318399c2c5caf7eeadcc37f359...       Connect
# 3  2aeca1a6c1ecf52b28b7f7646b6fb90563a417ee3e5dc3...       Connect
#
#              column2      column3
# 0  organization_name  device_type
# 1      People Mobile       Phones
# 2         ACME Phone       Phones
# 3  SmartDevices Inc.    Wearables

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=46bf1b32-bf21-4a37-b39f-eb384a2ba050' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
